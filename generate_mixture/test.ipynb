# %%
from generate_mixture import *
import librosa
import matplotlib.pyplot as plt
import random

# %%
audio, _ = librosa.load('/home/photon/Datasets/av-datas/lrs2_rebuild/audio/wav16k/min/cv/s1/6329893595522062514_00006_4.9973_6325440573560032726_00038_-4.9973.wav')

# %%
plt.plot(audio)

# %%
loud = random.random() * 8 - 33
print(loud)
plt.plot(reset_loudness(audio, loud))
# Out:
# -25.65844747147153
